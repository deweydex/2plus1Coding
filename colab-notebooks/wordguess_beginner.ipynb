# %% [markdown]
# # Word Guessing Game - Beginner Starter
#
# **Welcome!** This notebook helps you build a word guessing game (like Hangman).
#
# ## What you're starting with:
# - A word selection function that picks a random word
# - A display function that reveals guessed letters
# - Basic structure ready to expand
#
# ## Your tasks:
# 1. Add functionality to let the player guess a letter
# 2. Update the display to reveal correctly guessed letters
# 3. Track incorrect guesses and set a limit
# 4. Create a game loop that continues until win or lose
# 5. Add enhancements based on your interests
#
# ## How to use this notebook:
# 1. **Run the starter code** below to see what you have
# 2. **Copy code** to Claude.ai when you need help
# 3. **Paste improvements** back and test them
# 4. **Build incrementally** - one feature at a time!
#
# ---

# %%
import random

print("✓ Library imported successfully!")

# %%
def choose_word():
    """
    Selects a random word from a predefined list.
    
    Returns:
        str: A randomly selected word in uppercase
    """
    word_list = [
        "PYTHON",
        "CODING",
        "FUNCTION",
        "VARIABLE",
        "COMPUTER",
        "KEYBOARD",
        "PROGRAM",
        "ALGORITHM"
    ]
    return random.choice(word_list)


def display_word(word, guessed_letters):
    """
    Displays the word with guessed letters revealed and others as underscores.
    
    Parameters:
        word (str): The secret word to display
        guessed_letters (set): Set of letters the player has guessed
    
    Returns:
        str: The display string with underscores for unguessed letters
    """
    display = ""
    for letter in word:
        if letter in guessed_letters:
            display += letter + " "
        else:
            display += "_ "
    return display.strip()

# %%
# Run this cell to see the starter code in action!

print("=" * 50)
print("  WELCOME TO THE WORD GUESSING GAME!")
print("=" * 50)

# Choose a secret word
secret_word = choose_word()
guessed_letters = set()

print(f"\nYour mission: Guess the {len(secret_word)}-letter word!")
print(f"\nThe word: {display_word(secret_word, guessed_letters)}")

# Demo: what it looks like after guessing A and O
print("\n--- Demo: After guessing A and O ---")
guessed_letters.add('A')
guessed_letters.add('O')
print(f"The word: {display_word(secret_word, guessed_letters)}")

print("\n" + "=" * 50)
print("This is your starting point!")
print("Next: Add player guessing functionality.")
print("=" * 50)

# %% [markdown]
# ---
#
# ## Suggested Prompts for Claude.ai
#
# ### Step 1: Get Letter Guesses
# > "Add a function called get_letter_guess that asks the player to enter a letter, validates that it's a single letter, and returns it in uppercase."
#
# ### Step 2: Simple Guess Loop
# > "Create a loop that lets the player guess 5 letters, displaying the word state after each guess. Don't worry about win/lose logic yet."
#
# ### Step 3: Track Wrong Guesses
# > "Add a variable to track wrong guesses. When the player guesses a letter not in the word, increment the counter and display it."
#
# ### Step 4: Win/Lose Detection
# > "Add functions to check if the player won (all letters guessed) or lost (6 wrong guesses). Display appropriate messages."
#
# ### Step 5: Complete Game Loop
# > "Create the full game loop that continues until the player wins or loses, then displays the final message."
#
# ---
#
# ## Your Workspace

# %%
# Add your functions here!

# %%
# Test your game here!
